# %%
import pyspark
import pandas as pd
import numpy as np

# %%
filepath = "/home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt"

# %%
pdf = pd.read_csv(filepath, sep='\t')
pdf.head()
# Out:
#                                               Sample Chromosome     Start  \
# 0  BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_...          1     61735
# 1  BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_...          1   2291819
# 2  BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_...          1   2371329
# 3  BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_...          1   3210510
# 4  BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_...          1  16544783
#
#         End  Num_Probes  Segment_Mean
# 0   2288667         426       -0.1107
# 1   2370252          26       -0.7501
# 2   3210080         260       -0.1287
# 3  16542868        8006        0.0023
# 4  16785682          97       -0.1351

# %%
pdf.Sample.unique()
# Out:
# array(['BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594'], dtype=object)

# %%
from ontario.rdfizer.mapping.RMLMapping import *

# %%
#mapping = RMLMapping("/home/dsdl/PycharmProjects/SparkRDFizer/config/tcgamapping.ttl")

# %%
import rdflib
mappingfile = "/home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl"

# %%
g = rdflib.Graph()
g.load(mappingfile, format='n3')
for s, p, o in g:
    print(s, p, o)
# Out:
# ub1bL74C23 http://www.w3.org/ns/r2rml#objectMap ub1bL76C16
# ub1bL23C23 http://www.w3.org/ns/r2rml#predicate http://www.w3.org/2000/01/rdf-schema#label
# ub1bL65C23 http://www.w3.org/ns/r2rml#predicate http://gdc.cancer.gov/schema/end
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result http://www.w3.org/ns/r2rml#subjectMap ub1bL45C15
# ub1bL74C23 http://www.w3.org/ns/r2rml#predicate http://gdc.cancer.gov/schema/seg_mean
# ub1bL65C23 http://www.w3.org/ns/r2rml#objectMap ub1bL67C16
# ub1bL45C15 http://www.w3.org/ns/r2rml#template http://gdc.cancer.gov/schema/SNP_Result/{Sample}-[autoid]
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result http://www.w3.org/ns/r2rml#predicateObjectMap ub1bL57C23
# ub1bL18C15 http://www.w3.org/ns/r2rml#class http://gdc.cancer.gov/schema/SNP_Sample
# ub1bL18C15 http://www.w3.org/ns/r2rml#template http://gdc.cancer.gov/schema/Sample/{Sample}
# ub1bL85C16 http://www.w3.org/ns/r2rml#datatype http://www.w3.org/2001/XMLSchema#int
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result http://semweb.mmlab.be/ns/rml#logicalSource ub1bL40C19
# ub1bL104C23 http://www.w3.org/ns/r2rml#predicate http://www.w3.org/2000/01/rdf-schema#label
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#chromosome http://semweb.mmlab.be/ns/rml#logicalSource ub1bL94C19
# ub1bL67C16 http://www.w3.org/ns/r2rml#datatype http://www.w3.org/2001/XMLSchema#int
# ub1bL23C23 http://www.w3.org/ns/r2rml#objectMap ub1bL25C16
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#result http://www.w3.org/ns/r2rml#predicateObjectMap ub1bL32C23
# ub1bL85C16 http://semweb.mmlab.be/ns/rml#reference Num_Probes
# ub1bL25C16 http://www.w3.org/ns/r2rml#datatype http://www.w3.org/2001/XMLSchema#string
# ub1bL104C23 http://www.w3.org/ns/r2rml#objectMap ub1bL106C16
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result http://www.w3.org/ns/r2rml#predicateObjectMap ub1bL51C23
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#result http://semweb.mmlab.be/ns/rml#logicalSource ub1bL13C19
# ub1bL57C23 http://www.w3.org/ns/r2rml#objectMap ub1bL59C16
# ub1bL34C16 http://www.w3.org/ns/r2rml#parentTriplesMap file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result http://www.w3.org/ns/r2rml#predicateObjectMap ub1bL65C23
# ub1bL59C16 http://semweb.mmlab.be/ns/rml#reference Start
# ub1bL45C15 http://www.w3.org/ns/r2rml#class http://gdc.cancer.gov/schema/SNP_Result
# ub1bL25C16 http://semweb.mmlab.be/ns/rml#reference Sample
# ub1bL32C23 http://www.w3.org/ns/r2rml#objectMap ub1bL34C16
# ub1bL99C15 http://www.w3.org/ns/r2rml#class http://gdc.cancer.gov/schema/Chromosome
# ub1bL94C19 http://semweb.mmlab.be/ns/rml#source file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#chromosome http://www.w3.org/ns/r2rml#predicateObjectMap ub1bL104C23
# ub1bL40C19 http://semweb.mmlab.be/ns/rml#source file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt
# ub1bL51C23 http://www.w3.org/ns/r2rml#predicate http://gdc.cancer.gov/schema/chromosome
# ub1bL13C19 http://semweb.mmlab.be/ns/rml#referenceFormulation http://semweb.mmlab.be/ns/ql#TSV
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#chromosome http://www.w3.org/ns/r2rml#subjectMap ub1bL99C15
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#result http://www.w3.org/ns/r2rml#predicateObjectMap ub1bL23C23
# ub1bL99C15 http://www.w3.org/ns/r2rml#template http://gdc.cancer.gov/schema/Chormosome/{Chromosome}
# ub1bL53C16 http://www.w3.org/ns/r2rml#parentTriplesMap file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#chromosome
# ub1bL83C23 http://www.w3.org/ns/r2rml#predicate http://gdc.cancer.gov/schema/num_marks
# ub1bL51C23 http://www.w3.org/ns/r2rml#objectMap ub1bL53C16
# ub1bL57C23 http://www.w3.org/ns/r2rml#predicate http://gdc.cancer.gov/schema/start
# ub1bL59C16 http://www.w3.org/ns/r2rml#datatype http://www.w3.org/2001/XMLSchema#int
# ub1bL76C16 http://semweb.mmlab.be/ns/rml#reference Segment_Mean
# ub1bL94C19 http://semweb.mmlab.be/ns/rml#referenceFormulation http://semweb.mmlab.be/ns/ql#TSV
# ub1bL106C16 http://www.w3.org/ns/r2rml#datatype http://www.w3.org/2001/XMLSchema#string
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result http://www.w3.org/ns/r2rml#predicateObjectMap ub1bL74C23
# ub1bL32C23 http://www.w3.org/ns/r2rml#predicate http://gdc.cancer.gov/schema/result
# ub1bL83C23 http://www.w3.org/ns/r2rml#objectMap ub1bL85C16
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#result http://www.w3.org/ns/r2rml#subjectMap ub1bL18C15
# ub1bL67C16 http://semweb.mmlab.be/ns/rml#reference End
# ub1bL106C16 http://semweb.mmlab.be/ns/rml#reference Chromosome
# ub1bL76C16 http://www.w3.org/ns/r2rml#datatype http://www.w3.org/2001/XMLSchema#float
# ub1bL13C19 http://semweb.mmlab.be/ns/rml#source file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt
# ub1bL40C19 http://semweb.mmlab.be/ns/rml#referenceFormulation http://semweb.mmlab.be/ns/ql#TSV
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result http://www.w3.org/ns/r2rml#predicateObjectMap ub1bL83C23

# %%
class RMLSource (object):
    def __init__(self, sid, source, sourceuri, ref, iterator):
        self.sid = sid
        self.source = source
        self.uri = sourceuri
        self.ref = ref
        self.iterator = iterator
        self.subjectmap = None
        self.predobjmap = {}
    
    def __repr__(self):
        val  =  "<" + self.sid + "> \n" + \
                'rml:logicalSource [\n rml:source "' + \
                self.uri + '"; \n rml:referenceFormulation <' + \
                self.ref + ">; \n rml:iterator "+ str(self.iterator) + "\n];" +\
                '\n\n' + str(self.subjectmap)
        for pred in self.predobjmap:
           
            val += "\n\n rr:predicateObjectMap [ \n\t rr:predicate " + pred + ";"
            val += str(self.predobjmap[pred])
            val += "\n];"
        return val[:-1] + "."
    
    def set_subject_map(self, subjectmap):
        self.subjectmap = subjectmap
        
    def set_predicate_object_map(self, predobjmap):
        self.predobjmap = predobjmap
        
class RMLSubjectMap(object):
    def __init__(self, sid, smap, template, rdfclass):
        self.sid = sid
        self.smap = smap
        self.template = template
        self.rdfclass = rdfclass
    def __repr__(self):
        return ' rr:subjectMap[ \n\t\t rr:template "' + self.template + '"; \n\t\t rr:class ' + self.rdfclass + '\n\t];'
    
class RMLObjectMap(object):
    def __init__(self,maptype, objvalue=None, reference=None, template=None, termtype=None, datatype=None, language=None, parenttriplemap=None):
        
        self.maptype = maptype  # Const, Reference, Template, ParentTriplesMap
        self.objvalue = objvalue
        self.reference = reference
        self.termtype = termtype
        self.datatype = datatype
        self.language = language
        self.template = template
        self.parenttriplemap = parenttriplemap
    def __repr__(self):
        if self.maptype == 'Const':
            return '\n\t rr:objectMap [ \n\t\t rr:constant ' + self.objvalue + "\n\t ]"
        if self.maptype == 'Reference':
            return '\n\t rr:objectMap [ \n\t\t rml:reference "' + self.reference + '"\n\t ]'
        if self.maptype == 'Template':
            return '\n\t rr:objectMap [ \n\t\t rr:template "' + self.template + '"\n\t ]'
        if self.maptype == 'ParentTriplesMap':
            return '\n\t rr:objectMap [ \n\t\t rr:parentTriplesMap [\n\t\t ' + str(self.parenttriplemap) + "\n\t\t]\n\t ]"

# %%
sourcequery = '''
     prefix rr: <http://www.w3.org/ns/r2rml#> 
     prefix rml: <http://semweb.mmlab.be/ns/rml#> 
     prefix ql: <http://semweb.mmlab.be/ns/ql#> 
     SELECT DISTINCT *
     WHERE {                 
         # ?s rml:logicalSource ?source .
         # ?source rml:source ?sourceuri .
         # ?source rml:referenceFormulation ?ref .
         OPTIONAL { ?source rml:iterator  ?iterator.}    
         
         # ?s rr:subjectMap  ?smap. 
         # ?smap rr:template ?template .
         # ?smap rr:class ?rdfclass .
        
        # ?s  rr:predicateObjectMap ?pomap .
        # ?pomap rr:predicate ?predicate ;
        rr:objectMap ?omap.
        OPTIONAL{ ?omap rr:constant ?objval }
        OPTIONAL{ ?omap rml:reference ?oreference. }
        OPTIONAL{ 
                # ?omap rr:parentTriplesMap ?parentmap .
                # ?parentmap rr:subjectMap ?psmap .
                # ?psmap rr:template ?pstemplate . 
                # ?psmap rr:class ?psrdfclass .
                # ?parentmap rml:logicalSource ?plsource .
                # ?plsource rml:source ?psourceuri .
                # ?plsource rml:referenceFormulation ?psref .
                optional {?plsource rml:iterator ?psiterator }
                }
        OPTIONAL{ ?omap rr:template ?objtemplate.}
        OPTIONAL{ ?omap rr:datatype ?datatype .}
        OPTIONAL{ ?omap rr:termType ?termtype .}
        OPTIONAL{ ?omap rr:language ?lang .}
     }
  '''

# %%
sourceres = g.query(sourcequery)
print(len(sourceres))
for i in sourceres:
    print(str(i))
# Out:
# 8
# (None, None, rdflib.term.BNode('ub1bL67C16'), None, None, rdflib.term.Literal('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt'), rdflib.term.URIRef('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result'), rdflib.term.URIRef('http://semweb.mmlab.be/ns/ql#TSV'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/SNP_Result'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#int'), None, None, None, None, rdflib.term.BNode('ub1bL65C23'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/end'), None, None, None, rdflib.term.BNode('ub1bL40C19'), rdflib.term.Literal('End'), rdflib.term.BNode('ub1bL45C15'), rdflib.term.Literal('http://gdc.cancer.gov/schema/SNP_Result/{Sample}-[autoid]'))
# (None, None, rdflib.term.BNode('ub1bL59C16'), None, None, rdflib.term.Literal('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt'), rdflib.term.URIRef('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result'), rdflib.term.URIRef('http://semweb.mmlab.be/ns/ql#TSV'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/SNP_Result'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#int'), None, None, None, None, rdflib.term.BNode('ub1bL57C23'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/start'), None, None, None, rdflib.term.BNode('ub1bL40C19'), rdflib.term.Literal('Start'), rdflib.term.BNode('ub1bL45C15'), rdflib.term.Literal('http://gdc.cancer.gov/schema/SNP_Result/{Sample}-[autoid]'))
# (None, None, rdflib.term.BNode('ub1bL76C16'), None, None, rdflib.term.Literal('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt'), rdflib.term.URIRef('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result'), rdflib.term.URIRef('http://semweb.mmlab.be/ns/ql#TSV'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/SNP_Result'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'), None, None, None, None, rdflib.term.BNode('ub1bL74C23'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/seg_mean'), None, None, None, rdflib.term.BNode('ub1bL40C19'), rdflib.term.Literal('Segment_Mean'), rdflib.term.BNode('ub1bL45C15'), rdflib.term.Literal('http://gdc.cancer.gov/schema/SNP_Result/{Sample}-[autoid]'))
# (None, None, rdflib.term.BNode('ub1bL85C16'), None, None, rdflib.term.Literal('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt'), rdflib.term.URIRef('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result'), rdflib.term.URIRef('http://semweb.mmlab.be/ns/ql#TSV'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/SNP_Result'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#int'), None, None, None, None, rdflib.term.BNode('ub1bL83C23'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/num_marks'), None, None, None, rdflib.term.BNode('ub1bL40C19'), rdflib.term.Literal('Num_Probes'), rdflib.term.BNode('ub1bL45C15'), rdflib.term.Literal('http://gdc.cancer.gov/schema/SNP_Result/{Sample}-[autoid]'))
# (rdflib.term.Literal('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt'), rdflib.term.BNode('ub1bL94C19'), rdflib.term.BNode('ub1bL53C16'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/Chromosome'), rdflib.term.Literal('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt'), rdflib.term.URIRef('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result'), rdflib.term.URIRef('http://semweb.mmlab.be/ns/ql#TSV'), rdflib.term.URIRef('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#chromosome'), rdflib.term.URIRef('http://gdc.cancer.gov/schema/SNP_Result'), None, None, None, None, rdflib.term.URIRef('http://semweb.mmlab.be/ns/ql#TSV'), rdflib.term.BNode('ub1bL51C23'), rdflib.term.BNode('ub1bL99C15'), rdflib.term.URIRef('http://gdc.cancer.gov/schema/chromosome'), None, rdflib.term.Literal('http://gdc.cancer.gov/schema/Chormosome/{Chromosome}'), None, rdflib.term.BNode('ub1bL40C19'), None, rdflib.term.BNode('ub1bL45C15'), rdflib.term.Literal('http://gdc.cancer.gov/schema/SNP_Result/{Sample}-[autoid]'))
# (rdflib.term.Literal('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt'), rdflib.term.BNode('ub1bL40C19'), rdflib.term.BNode('ub1bL34C16'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/SNP_Result'), rdflib.term.Literal('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt'), rdflib.term.URIRef('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#result'), rdflib.term.URIRef('http://semweb.mmlab.be/ns/ql#TSV'), rdflib.term.URIRef('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result'), rdflib.term.URIRef('http://gdc.cancer.gov/schema/SNP_Sample'), None, None, None, None, rdflib.term.URIRef('http://semweb.mmlab.be/ns/ql#TSV'), rdflib.term.BNode('ub1bL32C23'), rdflib.term.BNode('ub1bL45C15'), rdflib.term.URIRef('http://gdc.cancer.gov/schema/result'), None, rdflib.term.Literal('http://gdc.cancer.gov/schema/SNP_Result/{Sample}-[autoid]'), None, rdflib.term.BNode('ub1bL13C19'), None, rdflib.term.BNode('ub1bL18C15'), rdflib.term.Literal('http://gdc.cancer.gov/schema/Sample/{Sample}'))
# (None, None, rdflib.term.BNode('ub1bL25C16'), None, None, rdflib.term.Literal('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt'), rdflib.term.URIRef('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#result'), rdflib.term.URIRef('http://semweb.mmlab.be/ns/ql#TSV'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/SNP_Sample'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'), None, None, None, None, rdflib.term.BNode('ub1bL23C23'), None, rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), None, None, None, rdflib.term.BNode('ub1bL13C19'), rdflib.term.Literal('Sample'), rdflib.term.BNode('ub1bL18C15'), rdflib.term.Literal('http://gdc.cancer.gov/schema/Sample/{Sample}'))
# (None, None, rdflib.term.BNode('ub1bL106C16'), None, None, rdflib.term.Literal('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt'), rdflib.term.URIRef('file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#chromosome'), rdflib.term.URIRef('http://semweb.mmlab.be/ns/ql#TSV'), None, rdflib.term.URIRef('http://gdc.cancer.gov/schema/Chromosome'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'), None, None, None, None, rdflib.term.BNode('ub1bL104C23'), None, rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), None, None, None, rdflib.term.BNode('ub1bL94C19'), rdflib.term.Literal('Chromosome'), rdflib.term.BNode('ub1bL99C15'), rdflib.term.Literal('http://gdc.cancer.gov/schema/Chormosome/{Chromosome}'))

# %%
rmlsources = {}

for r in sourceres:        
    sid = str(r.s)
    source = str(r.source)
    referenceform = str(r.ref) 
    iterator = r.iterator
    uri = r.sourceuri
    
    subjmap = r.smap
    template = r.template
    subjrdfclass = str(r.rdfclass)
    rmlsubject = RMLSubjectMap(sid, subjmap, template, subjrdfclass)
    
    pomap = str(r.pomap)
    predicate = str(r.predicate)
    objmap = str(r.omap)
    
    objconstval = str(r.objval)
    objreference = str(r.oreference)
    objtemplate = str(r.objtemplate)
        
    objlang = str(r.lang)
    if r.datatype:
        objdtype = str(r.datatype)
    else:
        objdtype = None
    if r.termtype:
        objtermtype = str(r.termtype)
    else:
        objtermtype = None
    
    objparentmap = str(r.parentmap)
    pslsource = str(r.plsource)
    psuri = str(r.psourceuri)    
    if r.psref:
        psrefformulation = str(r.psref)
    else:
        psrefformulation = None
        
    psiterator = str(r.psiterator)
    psmap = str(r.psmap)     
    if r.psrdfclass:
        psrdfclass = str(r.psrdfclass ) 
    else:
        psrdfclass = None
        
    pstemplate = str(r.pstemplate)
    
    mapType = 'Reference'
    if r.objval:
        mapType = 'Const'        
        rmlobject = RMLObjectMap(mapType,  objvalue=objconstval, reference=None, termtype=objtermtype, datatype=objdtype, language=objlang, parenttriplemap=None)
    elif r.objtemplate:
        mapType = "Template"
        rmlobject = RMLObjectMap(mapType, template=objtemplate,  objvalue=None, reference=None, termtype=objtermtype, datatype=objdtype, language=objlang, parenttriplemap=None)
    elif r.parentmap:
        mapType = 'ParentTriplesMap'
        psrmlsubject = RMLSubjectMap(objparentmap, psmap, pstemplate, psrdfclass)
        rmlobject = RMLObjectMap(mapType, parenttriplemap=psrmlsubject, objvalue=None, template=None, reference=None, termtype=objtermtype, datatype=objdtype, language=objlang)
    else:
        rmlobject = RMLObjectMap(mapType, reference=objreference, parenttriplemap=None, objvalue=None, template=None, termtype=objtermtype, datatype=objdtype, language=objlang)
    if sid in rmlsources:
        rmlsource = rmlsources[sid]
    else:
        rmlsource = RMLSource(sid, source, uri, referenceform, iterator)
        rmlsource.set_subject_map(rmlsubject)
        rmlsources[sid] = rmlsource
        
    rmlsource.predobjmap[predicate] = rmlobject

# %%
for s in rmlsources:  
    print(rmlsources[s])
    print()
# Out:
# <file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#result>
# rml:logicalSource [
#  rml:source "file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt";
#  rml:referenceFormulation <http://semweb.mmlab.be/ns/ql#TSV>;
#  rml:iterator None
# ];
#
#  rr:subjectMap[
# 		 rr:template "http://gdc.cancer.gov/schema/Sample/{Sample}";
# 		 rr:class http://gdc.cancer.gov/schema/SNP_Sample
# 	];
#
#  rr:predicateObjectMap [
# 	 rr:predicate http://gdc.cancer.gov/schema/result;
# 	 rr:objectMap [
# 		 rr:parentTriplesMap [
# 		  rr:subjectMap[
# 		 rr:template "http://gdc.cancer.gov/schema/SNP_Result/{Sample}-[autoid]";
# 		 rr:class http://gdc.cancer.gov/schema/SNP_Result
# 	];
# 		]
# 	 ]
# ];
#
#  rr:predicateObjectMap [
# 	 rr:predicate http://www.w3.org/2000/01/rdf-schema#label;
# 	 rr:objectMap [
# 		 rml:reference "Sample"
# 	 ]
# ].
#
# <file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#snp_result>
# rml:logicalSource [
#  rml:source "file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt";
#  rml:referenceFormulation <http://semweb.mmlab.be/ns/ql#TSV>;
#  rml:iterator None
# ];
#
#  rr:subjectMap[
# 		 rr:template "http://gdc.cancer.gov/schema/SNP_Result/{Sample}-[autoid]";
# 		 rr:class http://gdc.cancer.gov/schema/SNP_Result
# 	];
#
#  rr:predicateObjectMap [
# 	 rr:predicate http://gdc.cancer.gov/schema/start;
# 	 rr:objectMap [
# 		 rml:reference "Start"
# 	 ]
# ];
#
#  rr:predicateObjectMap [
# 	 rr:predicate http://gdc.cancer.gov/schema/chromosome;
# 	 rr:objectMap [
# 		 rr:parentTriplesMap [
# 		  rr:subjectMap[
# 		 rr:template "http://gdc.cancer.gov/schema/Chormosome/{Chromosome}";
# 		 rr:class http://gdc.cancer.gov/schema/Chromosome
# 	];
# 		]
# 	 ]
# ];
#
#  rr:predicateObjectMap [
# 	 rr:predicate http://gdc.cancer.gov/schema/end;
# 	 rr:objectMap [
# 		 rml:reference "End"
# 	 ]
# ];
#
#  rr:predicateObjectMap [
# 	 rr:predicate http://gdc.cancer.gov/schema/num_marks;
# 	 rr:objectMap [
# 		 rml:reference "Num_Probes"
# 	 ]
# ];
#
#  rr:predicateObjectMap [
# 	 rr:predicate http://gdc.cancer.gov/schema/seg_mean;
# 	 rr:objectMap [
# 		 rml:reference "Segment_Mean"
# 	 ]
# ].
#
# <file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/config/tcgamapping.ttl#chromosome>
# rml:logicalSource [
#  rml:source "file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt";
#  rml:referenceFormulation <http://semweb.mmlab.be/ns/ql#TSV>;
#  rml:iterator None
# ];
#
#  rr:subjectMap[
# 		 rr:template "http://gdc.cancer.gov/schema/Chormosome/{Chromosome}";
# 		 rr:class http://gdc.cancer.gov/schema/Chromosome
# 	];
#
#  rr:predicateObjectMap [
# 	 rr:predicate http://www.w3.org/2000/01/rdf-schema#label;
# 	 rr:objectMap [
# 		 rml:reference "Chromosome"
# 	 ]
# ].

# %%
import re
def getplaceholder(url):
    c = '(\{(.*?)\})'
    p = re.compile(c)
    #url = 'http://gdc.cancer.gov/schema/Sample/{Sample}'
    m = p.finditer(url)
    for a in m:
        return a.span(), a.group()
    
def autoincrement(url):
    c = '(\[(.*?)\])'
    p = re.compile(c)
    
    m = p.finditer(url)
    if m:
        for a in m:
            return a.span(), a.group()
    else:
        return None
    
url = 'http://gdc.cancer.gov/schema/Sample/{Sample}'
res = autoincrement(url)
if res:
    print(res)
else:
    print('Not autoincremtn')
# Out:
# Not autoincremtn

# %%
def applymapping(row, mappings, increment):
    result = []
    for m in mappings:
        submap = m.subjectmap
        subjmap = m.subjectmap.smap
        template = m.subjectmap.template
        subjrdfclass = m.subjectmap.rdfclass
        
        span, col = getplaceholder(template)
        start, end = span
        col = col[1:-1]
        
        autoinc = autoincrement(template)
        if autoinc:
            span = autoinc[0]
            increment[0] += 1
            subj = '<' + template[:start] + row[col] + template[end:span[0]] + str(increment[0]) + ">"
        else:
            subj = '<' + template[:start] +  row[col] + template[end:] + ">"
            
        triple = subj + ' <http://www.w3.org/2000/01/rdf-schema#type> <' + subjrdfclass + '> . '
        if triple not in result:
            result.append(triple)
        
        predobjmap = m.predobjmap
        for predicate in predobjmap:        
            maptype = predobjmap[predicate].maptype  # Const, Reference, Template, ParentTriplesMap
            objvalue = predobjmap[predicate].objvalue
            reference = predobjmap[predicate].reference
            termtype = predobjmap[predicate].termtype
            datatype = predobjmap[predicate].datatype
            language = predobjmap[predicate].language
            objtemplate = predobjmap[predicate].template
            parenttriplemap = predobjmap[predicate].parenttriplemap
            
            if maptype == 'Const':                
                triple = subj + " <" + predicate + "> <" + objvalue + "> . "
                if triple not in result:
                    result.append(triple)
            if maptype == 'Reference':
              
                if datatype:
                    if datatype == "http://www.w3.org/2001/XMLSchema#string":
                        triple = subj + " <" + predicate + '> "' + row[reference] + '"^^<'+ datatype + '> . '
                        if triple not in result:
                            result.append(triple)
                    elif datatype == "http://www.w3.org/2001/XMLSchema#int" or datatype == "http://www.w3.org/2001/XMLSchema#float":
                        triple = subj + " <" + predicate + '> "' + str(row[reference]) + '"^^<'+ datatype + '> . '
                        if triple not in result:
                            result.append(triple)
                    elif datatype == "http://www.w3.org/2001/XMLSchema#anyURI":
                        triple = subj + " <" + predicate + "> <" + row[reference] + "> . " 
                        if triple not in result:
                            result.append(triple)
                else:
                    triple = subj + " <" + predicate + "> <" + row[reference] + "> . "
                    if triple not in result:
                        result.append(triple)
                    
            if maptype == 'Template':
                span, col = getplaceholder(objtemplate)
                start, end = span
                col = col[1:-1]

                autoinc = autoincrement(objtemplate)
                if autoinc:
                    span = autoinc[0]               
                    obj = '<' + objtemplate[:start] + row[col] + objtemplate[end:span[0]] + str(increment[0]) + ">"
                else:
                    obj = '<' + objtemplate[:start] +  row[col] + objtemplate[end:] + ">"

                triple = subj + " <" + predicate + "> " + obj + ' . '
                if triple not in result:
                    result.append(triple)
                
            if maptype == 'ParentTriplesMap':
                #TODO: check if psuri is not same as current sourceuri
                #assuming reference triples are in the same file
                span, col = getplaceholder(parenttriplemap.template)
                start, end = span
                col = col[1:-1]

                autoinc = autoincrement(parenttriplemap.template)
                if autoinc:
                    span = autoinc[0]                    
                    obj = '<' + parenttriplemap.template[:start] + row[col] + parenttriplemap.template[end:span[0]] + str(increment[0]) + ">"
                else:
                    obj = '<' + parenttriplemap.template[:start] +  row[col] + parenttriplemap.template[end:] + ">"

                triple = subj  + " <" + predicate + "> " + obj + ' . '
                if triple not in result:
                    result.append(triple)
    #result = '\n' .join(result)
    #print(result)
    return result
                
def transform(f, sources):
    pdf = pd.read_csv(f, sep='\t')
    increment = [0]
    ttls = pdf.apply(applymapping, args=(sources,increment,), axis=1)
    return ttls

# %%
filesubj = {}
for s in rmlsources: 
    Source = rmlsources[s]
    print(Source.uri)
    if Source.uri in filesubj:
        filesubj[Source.uri].append(Source)
    else:
        filesubj[Source.uri] = [Source]
# Out:
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt
# file:///home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg.txt

# %%
for f in filesubj:
    ttls = transform(f, filesubj[f])
    
    flat_list = [item for sublist in ttls for item in sublist]

    ttls = list(set(flat_list))
    ttls = "\n".join(ttls)
    fpath = f[f.find(':')+3:f.rfind('/')]
    fname = f[f.rfind('/'):f.rfind('.')]
    with open(fpath+fname+'.nt', 'w+') as file:
        file.write(ttls)
    print(ttls)
# Out:
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-155> <http://gdc.cancer.gov/schema/start> "560570"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-96> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/3> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-167> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-389> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/18> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-431> <http://gdc.cancer.gov/schema/start> "18620743"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-81> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-207> <http://gdc.cancer.gov/schema/start> "6405536"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-252> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-239> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-161> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-92> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/3> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-214> <http://gdc.cancer.gov/schema/num_marks> "20"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-217> <http://gdc.cancer.gov/schema/start> "25126818"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-209> <http://gdc.cancer.gov/schema/seg_mean> "-0.0123"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-4> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/1> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-8> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-89> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-101> <http://gdc.cancer.gov/schema/end> "78998"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-168> <http://gdc.cancer.gov/schema/start> "51929000"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-297> <http://gdc.cancer.gov/schema/end> "9477960"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-422> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-55> <http://gdc.cancer.gov/schema/end> "12164245"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-383> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/17> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-412> <http://gdc.cancer.gov/schema/end> "4123863"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-312> <http://gdc.cancer.gov/schema/seg_mean> "-0.0243"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-402> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-368> <http://gdc.cancer.gov/schema/seg_mean> "-0.1068"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-383> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-406> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/19> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-22> <http://gdc.cancer.gov/schema/start> "118803936"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-25> <http://gdc.cancer.gov/schema/num_marks> "140"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-382> <http://gdc.cancer.gov/schema/seg_mean> "-0.2748"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-30> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-74> <http://gdc.cancer.gov/schema/num_marks> "661"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-396> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-129> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/4> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-209> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-438> <http://gdc.cancer.gov/schema/start> "33785435"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-2> <http://gdc.cancer.gov/schema/seg_mean> "-0.7501"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-442> <http://gdc.cancer.gov/schema/start> "49066298"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-33> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-82> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-111> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/4> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-383> <http://gdc.cancer.gov/schema/seg_mean> "-0.0268"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-287> <http://gdc.cancer.gov/schema/seg_mean> "-0.2899"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-107> <http://gdc.cancer.gov/schema/end> "63828222"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-165> <http://gdc.cancer.gov/schema/start> "32656814"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-327> <http://gdc.cancer.gov/schema/start> "18225647"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-358> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-407> <http://gdc.cancer.gov/schema/seg_mean> "-2.5853"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-435> <http://gdc.cancer.gov/schema/start> "24686548"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-51> <http://gdc.cancer.gov/schema/start> "189818"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-78> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-424> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-9> <http://gdc.cancer.gov/schema/seg_mean> "-0.0033"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-342> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-163> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-17> <http://gdc.cancer.gov/schema/seg_mean> "0.0203"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-31> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-81> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-201> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/8> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-415> <http://gdc.cancer.gov/schema/num_marks> "29002"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-154> <http://gdc.cancer.gov/schema/start> "381149"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-252> <http://gdc.cancer.gov/schema/num_marks> "3"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-237> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-328> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/14> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-405> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-441> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-27> <http://gdc.cancer.gov/schema/start> "143934634"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-129> <http://gdc.cancer.gov/schema/seg_mean> "-0.1811"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-65> <http://gdc.cancer.gov/schema/end> "146109366"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-189> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-279> <http://gdc.cancer.gov/schema/num_marks> "13"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-33> <http://gdc.cancer.gov/schema/start> "167743841"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-282> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/11> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-78> <http://gdc.cancer.gov/schema/start> "1925365"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-266> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/10> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-287> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/11> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-3> <http://gdc.cancer.gov/schema/start> "2371329"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Chormosome/3> <http://www.w3.org/2000/01/rdf-schema#label> "3"^^<http://www.w3.org/2001/XMLSchema#string> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-167> <http://gdc.cancer.gov/schema/end> "51926726"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-11> <http://gdc.cancer.gov/schema/num_marks> "7698"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-196> <http://gdc.cancer.gov/schema/seg_mean> "-0.0058"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-193> <http://gdc.cancer.gov/schema/seg_mean> "0.3675"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-222> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-301> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-62> <http://gdc.cancer.gov/schema/start> "86743283"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-230> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-443> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-417> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-38> <http://gdc.cancer.gov/schema/num_marks> "6052"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-447> <http://gdc.cancer.gov/schema/num_marks> "18"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-84> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-161> <http://gdc.cancer.gov/schema/end> "29869747"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-188> <http://gdc.cancer.gov/schema/num_marks> "38558"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-209> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/8> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-211> <http://gdc.cancer.gov/schema/end> "15922354"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-147> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-1> <http://gdc.cancer.gov/schema/end> "2288667"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-98> <http://gdc.cancer.gov/schema/end> "196741023"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-160> <http://gdc.cancer.gov/schema/num_marks> "1436"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-296> <http://gdc.cancer.gov/schema/num_marks> "23686"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-157> <http://gdc.cancer.gov/schema/end> "870479"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-408> <http://gdc.cancer.gov/schema/start> "55774927"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-151> <http://gdc.cancer.gov/schema/seg_mean> "-0.6856"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-392> <http://gdc.cancer.gov/schema/end> "79453155"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-183> <http://gdc.cancer.gov/schema/num_marks> "3"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-282> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-336> <http://gdc.cancer.gov/schema/start> "21999319"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-361> <http://gdc.cancer.gov/schema/end> "55761302"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Chormosome/12> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/Chromosome> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-143> <http://gdc.cancer.gov/schema/end> "171764601"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-347> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-436> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-196> <http://gdc.cancer.gov/schema/start> "126406824"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-218> <http://gdc.cancer.gov/schema/start> "31867132"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-434> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-423> <http://gdc.cancer.gov/schema/start> "42963142"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-389> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-328> <http://gdc.cancer.gov/schema/end> "24024866"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-302> <http://gdc.cancer.gov/schema/seg_mean> "-0.6337"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-337> <http://gdc.cancer.gov/schema/num_marks> "5"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-393> <http://gdc.cancer.gov/schema/seg_mean> "-0.1043"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-251> <http://gdc.cancer.gov/schema/end> "41639986"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-114> <http://gdc.cancer.gov/schema/start> "121370472"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-165> <http://gdc.cancer.gov/schema/num_marks> "5"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-81> <http://gdc.cancer.gov/schema/num_marks> "23"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-46> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-60> <http://gdc.cancer.gov/schema/num_marks> "41236"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-247> <http://gdc.cancer.gov/schema/start> "38796314"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-98> <http://gdc.cancer.gov/schema/start> "193168646"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-47> <http://gdc.cancer.gov/schema/seg_mean> "-0.0102"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-30> <http://gdc.cancer.gov/schema/num_marks> "175"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-196> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/7> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-141> <http://gdc.cancer.gov/schema/num_marks> "10224"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-220> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-366> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-437> <http://gdc.cancer.gov/schema/num_marks> "5"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-115> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-150> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-10> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/1> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-281> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-107> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-345> <http://gdc.cancer.gov/schema/seg_mean> "-0.1228"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-360> <http://gdc.cancer.gov/schema/end> "34056609"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-233> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-421> <http://gdc.cancer.gov/schema/start> "33904597"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-207> <http://gdc.cancer.gov/schema/seg_mean> "-0.0373"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-410> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-357> <http://gdc.cancer.gov/schema/end> "30165200"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-89> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-207> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-358> <http://gdc.cancer.gov/schema/start> "30165932"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-329> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/14> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-65> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-115> <http://gdc.cancer.gov/schema/num_marks> "3"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-177> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-205> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-47> <http://gdc.cancer.gov/schema/start> "246752129"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-37> <http://gdc.cancer.gov/schema/num_marks> "2"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-267> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-204> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/8> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-146> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-99> <http://gdc.cancer.gov/schema/num_marks> "56"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-270> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/10> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-85> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-19> <http://gdc.cancer.gov/schema/seg_mean> "0.0007"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-280> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-84> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-167> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-391> <http://gdc.cancer.gov/schema/end> "75779392"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-26> <http://gdc.cancer.gov/schema/start> "143842082"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-169> <http://gdc.cancer.gov/schema/seg_mean> "-1.6344"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-347> <http://gdc.cancer.gov/schema/num_marks> "3"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-87> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/3> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-324> <http://gdc.cancer.gov/schema/end> "105129828"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-146> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/5> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-91> <http://gdc.cancer.gov/schema/end> "140828142"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-122> <http://gdc.cancer.gov/schema/num_marks> "7435"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-252> <http://gdc.cancer.gov/schema/start> "41644131"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-426> <http://gdc.cancer.gov/schema/seg_mean> "-0.4599"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-406> <http://gdc.cancer.gov/schema/end> "55771003"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-101> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-387> <http://gdc.cancer.gov/schema/num_marks> "2"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-168> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/6> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-164> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-58> <http://gdc.cancer.gov/schema/end> "24376380"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-181> <http://gdc.cancer.gov/schema/end> "1287994"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-173> <http://gdc.cancer.gov/schema/seg_mean> "-0.4138"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-440> <http://gdc.cancer.gov/schema/end> "37353906"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-9> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-383> <http://gdc.cancer.gov/schema/num_marks> "2844"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-407> <http://gdc.cancer.gov/schema/end> "55771701"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-98> <http://gdc.cancer.gov/schema/num_marks> "1986"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-305> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-336> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-219> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/8> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-322> <http://gdc.cancer.gov/schema/num_marks> "20534"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-400> <http://gdc.cancer.gov/schema/start> "35358407"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-267> <http://gdc.cancer.gov/schema/end> "55420393"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-430> <http://gdc.cancer.gov/schema/start> "18147293"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-273> <http://gdc.cancer.gov/schema/end> "126354967"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-118> <http://gdc.cancer.gov/schema/seg_mean> "0.0023"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-185> <http://gdc.cancer.gov/schema/num_marks> "1918"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-303> <http://gdc.cancer.gov/schema/start> "30090657"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-428> <http://gdc.cancer.gov/schema/end> "18142004"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-218> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-31> <http://gdc.cancer.gov/schema/num_marks> "24"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-123> <http://gdc.cancer.gov/schema/seg_mean> "-0.0509"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-199> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-54> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-250> <http://gdc.cancer.gov/schema/end> "41064705"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-71> <http://gdc.cancer.gov/schema/start> "234040336"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-418> <http://gdc.cancer.gov/schema/end> "23920793"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-400> <http://gdc.cancer.gov/schema/seg_mean> "-0.431"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-343> <http://gdc.cancer.gov/schema/start> "76599286"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-343> <http://gdc.cancer.gov/schema/seg_mean> "0.727"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-26> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/1> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-238> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/9> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-104> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-312> <http://gdc.cancer.gov/schema/end> "19202714"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-388> <http://gdc.cancer.gov/schema/seg_mean> "0.0218"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-396> <http://gdc.cancer.gov/schema/end> "6987787"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-408> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-373> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/17> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-96> <http://gdc.cancer.gov/schema/num_marks> "19527"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-122> <http://gdc.cancer.gov/schema/seg_mean> "0.0083"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-247> <http://gdc.cancer.gov/schema/end> "39807498"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-361> <http://gdc.cancer.gov/schema/seg_mean> "0.001"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-213> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-153> <http://gdc.cancer.gov/schema/seg_mean> "-0.6654"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-49> <http://gdc.cancer.gov/schema/start> "248631988"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-347> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-51> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/2> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-438> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-6> <http://gdc.cancer.gov/schema/num_marks> "74"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-59> <http://gdc.cancer.gov/schema/seg_mean> "-0.6711"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-109> <http://gdc.cancer.gov/schema/start> "63841887"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-238> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-408> <http://gdc.cancer.gov/schema/end> "58586487"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-419> <http://gdc.cancer.gov/schema/num_marks> "4"^^<http://www.w3.org/2001/XMLSchema#int> .
# ...
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-45> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-284> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-100> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/3> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-364> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-336> <http://gdc.cancer.gov/schema/end> "22075280"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-187> <http://gdc.cancer.gov/schema/num_marks> "3583"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-75> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-42> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-239> <http://gdc.cancer.gov/schema/num_marks> "1260"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-369> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-42> <http://gdc.cancer.gov/schema/end> "223472019"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-152> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-123> <http://gdc.cancer.gov/schema/num_marks> "1346"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-174> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-323> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/13> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-110> <http://gdc.cancer.gov/schema/seg_mean> "0.005"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-94> <http://gdc.cancer.gov/schema/num_marks> "4008"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Chormosome/6> <http://www.w3.org/2000/01/rdf-schema#label> "6"^^<http://www.w3.org/2001/XMLSchema#string> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-392> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/18> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-5> <http://gdc.cancer.gov/schema/start> "16544783"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-40> <http://gdc.cancer.gov/schema/num_marks> "66"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-116> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-175> <http://gdc.cancer.gov/schema/start> "119953236"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-386> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/18> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-314> <http://gdc.cancer.gov/schema/num_marks> "2541"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://www.w3.org/2000/01/rdf-schema#label> "BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594"^^<http://www.w3.org/2001/XMLSchema#string> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-84> <http://gdc.cancer.gov/schema/seg_mean> "0.0045"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-303> <http://gdc.cancer.gov/schema/end> "33141726"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-24> <http://gdc.cancer.gov/schema/end> "143494498"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-71> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-131> <http://gdc.cancer.gov/schema/start> "1934664"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-359> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/16> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-361> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-352> <http://gdc.cancer.gov/schema/start> "16269368"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-404> <http://gdc.cancer.gov/schema/num_marks> "1396"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-351> <http://gdc.cancer.gov/schema/seg_mean> "-0.0807"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-164> <http://gdc.cancer.gov/schema/num_marks> "569"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-76> <http://gdc.cancer.gov/schema/start> "819470"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-134> <http://gdc.cancer.gov/schema/start> "17601444"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-213> <http://gdc.cancer.gov/schema/num_marks> "5479"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-120> <http://gdc.cancer.gov/schema/end> "172501371"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-275> <http://gdc.cancer.gov/schema/end> "133769379"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-125> <http://gdc.cancer.gov/schema/seg_mean> "1.0786"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-265> <http://gdc.cancer.gov/schema/start> "50070600"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-367> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/16> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-64> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-381> <http://gdc.cancer.gov/schema/start> "74547688"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-48> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-118> <http://gdc.cancer.gov/schema/start> "132206355"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-119> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-251> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-349> <http://gdc.cancer.gov/schema/num_marks> "3201"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-322> <http://gdc.cancer.gov/schema/end> "100001059"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-110> <http://gdc.cancer.gov/schema/end> "68494771"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-184> <http://gdc.cancer.gov/schema/num_marks> "676"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-66> <http://gdc.cancer.gov/schema/num_marks> "2037"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-97> <http://gdc.cancer.gov/schema/start> "193155915"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-11> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-136> <http://gdc.cancer.gov/schema/start> "21370468"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-177> <http://gdc.cancer.gov/schema/num_marks> "2"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-321> <http://gdc.cancer.gov/schema/start> "68674167"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-268> <http://gdc.cancer.gov/schema/seg_mean> "-2.0543"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-5> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-300> <http://gdc.cancer.gov/schema/end> "24798554"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-412> <http://gdc.cancer.gov/schema/num_marks> "106"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-188> <http://gdc.cancer.gov/schema/start> "30742027"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/Sample/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594> <http://gdc.cancer.gov/schema/result> <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-199> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-416> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/20> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-450> <http://gdc.cancer.gov/schema/seg_mean> "-0.0261"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-312> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/13> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-286> <http://gdc.cancer.gov/schema/end> "55595864"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-225> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/8> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-361> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/16> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-106> <http://gdc.cancer.gov/schema/chromosome> <http://gdc.cancer.gov/schema/Chormosome/4> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-81> <http://gdc.cancer.gov/schema/start> "6609441"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-335> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-96> <http://gdc.cancer.gov/schema/start> "162426460"^^<http://www.w3.org/2001/XMLSchema#int> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-126> <http://www.w3.org/2000/01/rdf-schema#type> <http://gdc.cancer.gov/schema/SNP_Result> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-420> <http://gdc.cancer.gov/schema/seg_mean> "0.0068"^^<http://www.w3.org/2001/XMLSchema#float> .
# <http://gdc.cancer.gov/schema/SNP_Result/BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594-33> <http://gdc.cancer.gov/schema/num_marks> "5"^^<http://www.w3.org/2001/XMLSchema#int> .

# %%
f[f.find(':')+3:f.rfind('/')], f[f.rfind('/')+1:f.rfind('.')]
# Out:
# ('/home/guillermobet/Documents/Fraunhofer/ProjectIASIS/SimpleRDFizer/sample-data',
#  'BROSE_p_TCGASNP_195_196_197_N_GenomeWideSNP_6_F12_1039594.grch38.seg')
